# %% [markdown]
# This File Downloads images from the images URL so I can use them for kmeans algorithm

# %%
#import packages 
from collections import Counter
from sklearn.cluster import KMeans
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import requests
from tqdm import tqdm, tqdm_notebook
tqdm_notebook().pandas()
import wget
from csv import reader
import os.path

# %%
df = pd.read_csv("full_emotion_color.csv")
df.head()
# Out:
#                                     Category                   Artist  \
# ID
# 58c6237dedc2c9c7dc0de1ae       Impressionism  Charles Courtney Curran
# 577280dfedc2cb3880f28e76   Neo-Expressionism             Keith Haring
# 57727f2dedc2cb3880ed5fa9  Post-Impressionism       Jozsef Rippl-Ronai
# 58d1240cedc2c94f900fc610              Cubism             Vadym Meller
# 57727de7edc2cb3880e91f26         Romanticism             David Wilkie
#
#                                                                   Title  Year  \
# ID
# 58c6237dedc2c9c7dc0de1ae                       In the Luxembourg Garden  1889
# 577280dfedc2cb3880f28e76                The Marriage of Heaven and Hell  1984
# 57727f2dedc2cb3880ed5fa9  Uncle Piacsek in front of the Black Sideboard  1906
# 58d1240cedc2c94f900fc610           Monk. For the Play &#39;Mazeppa&#39;  1920
# 57727de7edc2cb3880e91f26                   The Defence of Sarago&#231;a  1828
#
# ...

# %%
# creating a csv with only the Image URLs
df_new=df['Image URL'] 
df_new.to_csv("output.csv",index=False)

# %%
links = df['Image URL'].to_list()

# %%
for link in links:
    print(link)
    wget.download(link)
# Out:
# https://uploads0.wikiart.org/images/roger-fry/essay-in-abstract-design-1915.jpg
# https://uploads3.wikiart.org/images/rosalba-carriera/a-tyrolean-innkeeper-1728.jpg
# https://uploads2.wikiart.org/images/rene-bertholo/nuage-azagury-1971.jpg
# https://uploads0.wikiart.org/images/mark-rothko/no-2-1964.jpg
# https://uploads2.wikiart.org/00123/images/daniel-ridgway-knight/reverie-1866.jpg
# https://uploads2.wikiart.org/images/morris-louis/pillar-of-fire-1961.jpg
# https://uploads2.wikiart.org/images/camille-corot/the-woman-with-a-pearl-1870.jpg
# https://uploads3.wikiart.org/images/richard-smith/slot-machine-1962-1.jpg
# https://uploads3.wikiart.org/images/wassily-kandinsky/blue-rider-1903.jpg
# https://uploads3.wikiart.org/images/artemisia-gentileschi/woman-playing-a-lute.jpg
# https://uploads6.wikiart.org/images/eduardo-viana/lou-a-de-barcelos-1915.jpg
# https://uploads4.wikiart.org/images/bertalan-por/woman-with-a-hat-1905.jpg
# ...
